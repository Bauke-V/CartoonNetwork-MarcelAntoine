# %%
import os
import json
import pandas as pd
import time
import ast
from pydantic import BaseModel
from pydantic_core import from_json
import glob
from typing import List, Optional
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_together import ChatTogether
import re
import unicodedata
from pathlib import Path

# %%
import session_info
session_info.show
# Out:
# <function session_info.main.show(na=True, os=True, cpu=False, jupyter=None, dependencies=None, std_lib=False, private=False, write_req_file=False, req_file_name=None, html=None, excludes=['builtins', 'stdlib_list'])>

# %%
TOGETHER_API_KEY= "d979400b673cec622ddde38b0307fc18197e34bf957a91f1b1d58ba647012461"
model="meta-llama/Llama-4-Maverick-17B-128E-Instruct-FP8"

# %%
class NER(BaseModel):
    personne: Optional[list] = None
    lieu: Optional[list] = None
    organisation: Optional[list] = None

# %%
def parse_llm_response(response, basemodel_class = NER):
  try:
    result = basemodel_class.model_validate(from_json(response.content, allow_partial = True))
    category_entity = []
    for entity in result:
      if entity[1] != None:
        category = entity[0]
        entity_text_list = entity[1]

        for ent in entity_text_list:
          category_entity.append((ent, category))

    return category_entity

  except:
    return []

# %%
question = "Extrais les entités nommées pertinentes de la phrase suivante."

# %%
personality = "Tu es historien(ne) et spécialiste en littérature, avec une expertise des journaux historiques belges en langue française, des dessins humoristiques qui y apparaissent  et de l'annotation des entités nommées."
template_0=f"{personality}"

# %%
def llm_output(content_user,model_1=model,content_sys=template_0,basemodel_class = NER):
    
    llm = ChatTogether(
      model=model_1,
      temperature=0,
      api_key=TOGETHER_API_KEY,
  )
    messages=[
        (
            "system", content_sys,
        ),
        (
            "human",content_user,
        ),
    ]

    response = llm.invoke(messages)
    print("RESPONSE CONTENT:\n", response.content)
    test_result = basemodel_class.model_validate(from_json(response.content, allow_partial = True))
    result = test_result.model_dump()
    
    return result

# %%
def text_splitter(sample_text, chunk_size = 64000):
  custom_text_splitter = RecursiveCharacterTextSplitter(
      chunk_size = chunk_size,
      chunk_overlap  = 20,
      length_function = len,

  )
  texts = custom_text_splitter.create_documents([sample_text])
  texts_content = [text.page_content for text in texts]

  return texts_content

# %%
schema_entity={"personne": ["string"],
        "lieu": ["string"],
        "organisation": ["string"]
      }

# %%
categories = """
personne : noms propres de personnes,
lieu : noms propres de lieux,
organisation : noms propres d’organisations"""

# %%
def preprocess_text(text):
    text = unicodedata.normalize("NFKC", text)  
    text = re.sub(r"(\w+)-\n(\w+)", r"\1\2", text)  
    text = re.sub(r"\n+", " ", text)
    text = re.sub(r"\s+", " ", text).strip()  
    text = re.sub(r"(\w)([.,;!?])", r"\1 \2", text)  
    return text

# %%
input_folder = Path(r"C:\Users\bauke\OneDrive - KU Leuven\Documents\Documenten\5 digital humanities\stage\articles-verbetering")
output_data = []

data = ({"filename": [], "text": []})

for file_path in input_folder.glob("*.txt"):
    with open(file_path, "r", encoding="utf-8") as f:
        text = f.read()
    
    data["filename"].append(file_path.name)
    data["text"].append(text)

df = pd.DataFrame(data)
        
df["cleaned_text"] = df["text"].apply(preprocess_text)

# %%
df["chunks"] = df.cleaned_text.apply(text_splitter)
df = df.explode("chunks")

# %%
chunk_size=20000
templates_text=[]
for text in df["chunks"]:
  chunks=text_splitter(text, chunk_size)
  templates=[]
  for sentence in chunks:
  
    template_1 = f"""
          Tu es un expert des journaux historiques belges en français. 
          Ta tâche est d'extraire les entités nommées pertinentes de la phrase donnée selon les catégories suivantes :
          {categories}

          Réponds uniquement en format JSON, sans ajouter de commentair et n’incluez pas de mise en forme Markdown comme les triples accents graves (```).
          Le format JSON attendu est le suivant :
          {schema_entity}

          Voici quelques exemples pour t’inspirer :

          Exemple 1 :
          Phrase : <<<Le roi Léopold II a visité Bruxelles en 1895.>>>

          Étape 1 : Identifier les entités nommées potentielles
          - roi Léopold II
          - Bruxelles

          Étape 2 : Catégoriser chaque entité
          - roi Léopold II : personne
          - Bruxelles : lieu

          Étape 3 : Formater la réponse

          {{
            "personne": ["roi Léopold II"],
            "lieu": ["Bruxelles"],
            "organisation": []
          }}
          Exemple 1 :
          Phrase : <<<Marcel Antoine , président fondateur du groupement « La Mine souriante ». est décédé inopinément à son domicile , à Bruxelles .>>>

          Étape 1 : Identifier les entités nommées potentielles
          - Marcel Antoine
          - La Mine souriante
          - Bruxelles

          Étape 2 : Catégoriser chaque entité
          - Marcel Antoine : Personne
          - La Mine souriante : organisation
          - Bruxelles : lieu

          Étape 3 : Formater la réponse

          {{
            "personne": ["Marcel Antoine"],
            "lieu": ["Bruxelles"],
            "organisation": ["La Mine souriante]
          }}

          Exemple 1 :
          Phrase : <<<"13 h . 30 RADIO-SCHAERBEEK : « Slache-Magazine » de Marcel Antoine">>>

          Étape 1 : Identifier les entités nommées potentielles
          - Marcel Antoine
          - RADIO-SCHAERBEEK
          

          Étape 2 : Catégoriser chaque entité
          - Marcel Antoine : Personne
          - RADIO-SCHAERBEEK : organisation

          Étape 3 : Formater la réponse

          {{
            "personne": ["Marcel Antoine"],
            "lieu": [],
            "organisation": ["RADIO-SCHAERBEEK"]
          }}


          Maintenant, n’utilise pas les exemples ci-dessus, ils ne servent que de référence.

          Question : {question}
          Phrase à analyser : <<<{sentence}>>>

          Réponse :
        """
    templates.append(template_1)
  templates_text.append(templates)

# %%
json_output = {}

for index, (templates, row) in enumerate(zip(templates_text, df.to_dict(orient="records"))):
    ner_result = {
        "personne": [],
        "lieu": [],
        "organisation": []
    }

    for sub_template in templates:
        sub_result = llm_output(sub_template, model, template_0)

        for key in ner_result.keys():
            if key in sub_result and isinstance(sub_result[key], list):
                ner_result[key] += sub_result[key]

    for key in ner_result:
        ner_result[key] = list(set(ner_result[key]))

    json_output[row["filename"]] = {
        "text": row["text"],
        "cleaned_text": row["cleaned_text"],
        "people": ner_result["personne"],
        "locations": ner_result["lieu"],
        "organisations": ner_result["organisation"]
    }

llama_results = "llama_results3.json"
with open(llama_results, "w", encoding="utf-8") as f:
    json.dump(json_output, f, indent=4, ensure_ascii=False)

import pandas as pd
df_output = pd.DataFrame.from_dict(json_output, orient="index").reset_index(names="filename")
# Out:
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine", "E . Delhaes"],
#   "lieu": [],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine", "Georges Villiers", "Paginrani", "Pills", "Tabet", "Maurice Gilman", "Pagllarani", "Rsrt"],
#   "lieu": ["Spa", "Aranjuez", "Bruxelles"],
#   "organisation": ["Radio-Schaerbeek-Bruxelles", "Opêra-Gomlque", "Opéra-Comique"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine"],
#   "lieu": ["Bruxelles"],
#   "organisation": ["Radio-Schaerbeek-Bruxelles", "Salon de la mine souriante"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine", "Adolphe Mar", "Reginald Denny", "Jean-Pierre Aumont", "Paul Reboux", "Abel Hermant", "Maurice de Waleffe", "René CHASSART", "Ritche"],
#   "lieu": ["Bruxelles", "Mon Village", "Touraine"],
#   "organisation": ["La Mine Souriante", "Radio qui rit"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": [],
#   "lieu": ["Bruxelles"],
#   "organisation": ["LES SUN'KIST'S", "Radio-Schaerbeek"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine"],
#   "lieu": [],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Jules Slache", "Robert Bebronne", "Marcel Antoine", "Bicard", "Bouif", "Charlôt"],
#   "lieu": ["Bruxelles", "Schaerbeek", "Marolles"],
#   "organisation": ["Radio-Schaerbeek", "Cassandre"]
# }
# RESPONSE CONTENT:
#  {"personne": ["Marcel Antoine"], "lieu": [], "organisation": ["RADIO-SCHAERBEEK", "Slache-Magazine"]}
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine"],
#   "lieu": ["Bruxelles"],
#   "organisation": ["Radio-Schaerbeek-Bruxelles"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine", "P. V."],
#   "lieu": ["Bruxelles"],
#   "organisation": ["Radio-Schaerbeek-Bruxelles", "Ordre de la Couronne", "La Mine Souriante"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Père Bugeaud", "Napoléon", "Maurice Chevalier", "Marcel Antoine"],
#   "lieu": ["Schaerbeek", "Bruxelles"],
#   "organisation": ["Radio-Schaerbeek-Bruxelles"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine", "Bach", "Laverne", "Monique BERT", "Madeleine Soria", "Lucien Rosenberg", "Louis Verneuil", "Georges Beer"],
#   "lieu": ["Bruxelles", "Pont de l'Alma"],
#   "organisation": ["RADIO-SCHAERBEEK-BRUXELLES", "Radio-Schaerbeek-Bruxelles"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine", "Tinno Rossi"],
#   "lieu": [],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine", "Pascal", "Chilon", "Molière", "Tino Rossi", "Mireille"],
#   "lieu": ["Espagne", "Congo", "lune"],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine", "Noé"],
#   "lieu": ["Molenbeek", "Bruxelles"],
#   "organisation": ["RADIO-SCHAERBEEK"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine", "Slache", "Charlot", "Don Quichotte", "Grock", "Rittche", "Adolphe", "Adolphine", "Barju", "Adémaï", "Pantoufle", "Madame Blanche", "Madame Slache", "Marius", "Fonson", "Wicheler", "Gustave Libeau", "Charles Mahieu", "M. Beulemans", "Maurice Chevalier", "Albert Préjean", "Henri Garat", "Rabelais"],
#   "lieu": ["rue de la Bourse"],
#   "organisation": ["Radio-Schaerbeek"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Esther Delterne", "Esther", "Slache", "Racine", "Maurice", "Marcel ANTOINE"],
#   "lieu": ["Bruxelles", "Wallonie", "Lessines", "Belgique", "Casino de Paris"],
#   "organisation": ["Radio-Schaerbeek-Bruxelles", "Radio - Schaerbeek - Bruxelles"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Slache", "Henri Garrat"],
#   "lieu": ["Molenbeek", "îles Hawaï"],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["MARCEL ANTOINE", "OLIVE", "Marcel ANTOINE"],
#   "lieu": ["LA TRINITE"],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine"],
#   "lieu": [],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine", "Lise Coliny"],
#   "lieu": [],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine", "Paul Colline", "Joyeux Barju", "Joyeux Pierre Dac", "René Dorin"],
#   "lieu": ["Montmartre"],
#   "organisation": ["cabaret Fantaisie"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine", "Bach", "Laverne", "Milton", "Ray Ventura"],
#   "lieu": [],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Lise COLINY", "Marcel Antoine"],
#   "lieu": [],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Lise Coliny", "Line Coliny"],
#   "lieu": [],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine", "Lezay-marnésia", "La Fontaine", "Collin d'Harleville"],
#   "lieu": [],
#   "organisation": ["Radio-Schaerbeek"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine"],
#   "lieu": ["Semois", "Lesse", "mer du Nord", "côte d'Azur", "Méditerranée"],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["LISE COLINY", "Lise Coliny", "Lise COliny", "Don Quichotte", "Cervantès"],
#   "lieu": [],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Jules SLACHE", "Marcel Antoine", "Olive", "Hubert", "le vieil Onde", "Toutouneke"],
#   "lieu": ["Bruxelles", "Molenbeek"],
#   "organisation": ["Radio-Schaerbeek-Bruxelles"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine", "Chamfort", "Rabelais", "Beaumarchais", "Piron"],
#   "lieu": [],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["MARCEL ANTOINE", "Bach", "Ouvrard", "Noël-Noël", "Figaro"],
#   "lieu": [],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine", "Père Lachaise"],
#   "lieu": ["Québec", "Gaz-Bec"],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Lise Coliny", "LISE COLINY", "M . A ."],
#   "lieu": [],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel ANTOINE"],
#   "lieu": ["Grand Place"],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Lise Coliny", "Tino Rossi", "Bonaparte", "Slache", "Marcel Antoine"],
#   "lieu": ["Bruxelles"],
#   "organisation": ["Radio-Schaerbeek-Bruxelles"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine", "Bach", "Joséphine Baker"],
#   "lieu": ["Afrique", "Maroc", "Madagascar"],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Lise Coliny", "Lucienne Boyer", "M. A."],
#   "lieu": [],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel ANTOINE", "Alfred de Musset", "Madame Blanche", "Marcel Antoine"],
#   "lieu": ["Bruxelles"],
#   "organisation": ["La Foire de Bruxelles"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel ANTOINE", "Marcel Antoine", "Adam", "Eve", "Edith", "Maria"],
#   "lieu": [],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Lise Coliny", "M. A."],
#   "lieu": [],
#   "organisation": ["Radio-Schaerbeek"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine", "Marcel ANTOINE"],
#   "lieu": [],
#   "organisation": ["Théâtre"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Lise Coliny", "Lise COLINY", "Cupidon"],
#   "lieu": [],
#   "organisation": ["M . A ."]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Lise Coliny", "Marcel Antoine"],
#   "lieu": [],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine", "Nénesse", "Prosper", "Totor-le-Balafré"],
#   "lieu": [],
#   "organisation": ["Police-Secours"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Mireille", "Marcel Antoine", "Jean Nohain"],
#   "lieu": [],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Lise Coliny", "Marcel Antoine"],
#   "lieu": [],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Lise Coliny", "Lejal", "MARCEL ANTOINE"],
#   "lieu": [],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Lise Coliny"],
#   "lieu": [],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Lise Coliny", "Verlaine"],
#   "lieu": [],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel ANTOINE", "Marcel Antoine"],
#   "lieu": ["Rue"],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Lise Coliny", "Lucienne Boyer", "RENE DORIN", "MARCEL ANTOINE"],
#   "lieu": [],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine", "Franz Lehar", "Bach", "Victor Boucher"],
#   "lieu": [],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel ANTOINE", "Adam", "Philémon", "Baucis", "Roméo", "Juliette", "don Quichotte", "Sancho", "Slache", "Olive", "Robinson", "Vendredi", "Pèlissou", "Marcel Antoine"],
#   "lieu": [],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel ANTOINE"],
#   "lieu": [],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Lise Coliny", "Lise Cbliny", "Marcel ANTOINE", "Chevalier", "Ouvrard"],
#   "lieu": [],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine", "Lise COLINY", "Fernand COPPIETERS", "Marcel ANTOINE"],
#   "lieu": ["Europe"],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine"],
#   "lieu": ["Europe", "l’Europe", "Babel"],
#   "organisation": ["Radio-Schaerbeek"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Lise Coliny", "Marcel Antoine"],
#   "lieu": [],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Lise Coliny", "Marcel ANTOINE"],
#   "lieu": [],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel ANTOINE", "Marcel Antoine"],
#   "lieu": [],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine", "Lise Coliny", "Théo Parlon", "Dalbret", "Georgel", "Yvette Guilbert", "LISE COLIN", "THEO PARLON"],
#   "lieu": [],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel ANTOINE", "Lise COLINY"],
#   "lieu": [],
#   "organisation": ["Music-Hall"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Lise Coliny", "Marcel Antoine", "Noël-Noël", "Crock", "Liverdan"],
#   "lieu": [],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine", "Chevalier", "Trenet", "La Houpa", "Ray Ventura"],
#   "lieu": [],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Lise Coliny", "LILIAN HARVEY", "Chevalier", "Grace Moore", "Jeannette Mac Donald", "Garat", "Gravey", "Marcel ANTOINE"],
#   "lieu": [],
#   "organisation": ["Radio"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine", "Alcibiade", "Charlet"],
#   "lieu": [],
#   "organisation": ["Les Chiens Fantaisie"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine"],
#   "lieu": [],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Lise Coliny", "Tino Rost", "Henri Garat", "Marcel Antoine"],
#   "lieu": [],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine"],
#   "lieu": ["Midi", "Lagardère"],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Lise Coliny"],
#   "lieu": [],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Olive", "Chustave", "Hubert", "Humbert", "Arthur"],
#   "lieu": [],
#   "organisation": ["Radio-Schaerbeek", "Loterie Coloniale", "Nive-Your"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Jules SLACHE", "Marcel ANTOINE", "Toutouneke"],
#   "lieu": ["Rue Le Lorrain"],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Lyne Clevers", "Charles Trenet", "Marcel Antoine", "Lyne Clovers"],
#   "lieu": [],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine"],
#   "lieu": [],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Lise Coliny", "MARCEL ANTOINE"],
#   "lieu": [],
#   "organisation": ["Au Coin du Feu", "La Barque à Carron"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Joseph Bouglione", "Marcel Antoine", "Mlle Simonne Amiaux", "M. Rouchy"],
#   "lieu": [],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine", "Fernand COPPIETERS", "Lise COLINY", "Marcel ANTOINE"],
#   "lieu": [],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine", "Phébus"],
#   "lieu": [],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Lise Coliny", "Marcel Antoine"],
#   "lieu": ["Léthé", "Styx"],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Fernandel", "Florelle", "Marcel Antoine"],
#   "lieu": [],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine", "Lise Coliny", "Florelle", "Fernandel"],
#   "lieu": [],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Lise Coliny"],
#   "lieu": [],
#   "organisation": ["Radio-SCHAERBEEK"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine", "Don José", "Carmen", "Cupidon"],
#   "lieu": ["Espagne", "Bruxelles", "Bohème"],
#   "organisation": ["Fonde de Radio-Schaerbeek-Bruxelles"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Lise Coliny", "Noël-Noël", "M. A."],
#   "lieu": [],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Lise Coliny", "M . A"],
#   "lieu": ["tour de Babei"],
#   "organisation": ["Radio-Schaerbeek"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel ANTOINE", "Bach", "Ouvrard", "Fernande", "Marcel Antoine"],
#   "lieu": [],
#   "organisation": ["Soldats Fantaisie Militaire"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel ANTOINE", "Fernand COPPIETERS", "Lise COLINY"],
#   "lieu": [],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel ANTOINE", "Marcel Antoine"],
#   "lieu": [],
#   "organisation": ["Imitateurs Fantaisie"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Lise Coliny", "Lise COLINY"],
#   "lieu": [],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Lise Coliny", "M. A."],
#   "lieu": [],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Lise Coliny", "Lise COLINY", "M . A"],
#   "lieu": [],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel ANTOINE", "Lise COLINY"],
#   "lieu": [],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["M. Antoine", "Pierre Dao", "Nions Lisa"],
#   "lieu": ["Gheel", "Charenton"],
#   "organisation": ["Les Loufoques"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Lise Coliny", "M. A."],
#   "lieu": [],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel ANTOINE", "Fernand COPPIETERS", "Lise COLINY"],
#   "lieu": [],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel ANTOINE"],
#   "lieu": [],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Lise Coliny", "Lise COliny", "Marcel Antoine", "Yvonne"],
#   "lieu": [],
#   "organisation": ["Royal Institut"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["MARCEL ANTOINE", "Marcel Antoine"],
#   "lieu": ["Amérique"],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine", "Antonio Marcellus", "Olive de la Canebière", "Dechambre", "Juanita", "Rise Solignu", "Toutourne", "Laplanque", "Lecordonnier", "Le général Atchoum Sapart", "Olive", "Léopold", "E. Furibart", "Amand Verlache"],
#   "lieu": ["Bruxelles", "Berg-op-Zoom", "la Canebière"],
#   "organisation": ["RADIO-SCHAERBEEK-BRUXELLES"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine"],
#   "lieu": [],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Lise COLINY", "Marcel ANTOINE"],
#   "lieu": [],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine", "Lise Coliny"],
#   "lieu": ["Bruxelles"],
#   "organisation": ["Radio-Schaerbeek"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine"],
#   "lieu": [],
#   "organisation": ["RADIO-CONFERENCES"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["M. H. Vanhuffel", "Camille Huysmans", "M. Laroche", "Fontaine", "M. Van Assche", "Marcel Antoine"],
#   "lieu": ["KOEKELBERG", "Maison communale de Koekelberg"],
#   "organisation": ["conseil de la Maison communale", "comité organisateur", "sociétés de la commune"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Jacques HERVENS", "Marcel Antoine"],
#   "lieu": ["rue Royale", "Bruxelles", "rue de la Croix de Fer"],
#   "organisation": ["APOLLO"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Henri Lemaire", "Roméo Dumoulin", "P. François", "J. Canneel", "J. Ancia", "J. Kïecker", "A. Lenoir", "Marcel Antoine"],
#   "lieu": ["Bruxelles", "Belgique"],
#   "organisation": ["Groupement des dessinateurs humoristes belges", "La Mine souriante"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["ALICE HELLEMANS", "JACQUES STEHMAN", "MARCEL ANTOINE", "DELAUNOY", "MICHEL MATTHYS"],
#   "lieu": ["Anvers", "PALAIS DES BEAUX ARTS"],
#   "organisation": ["BISTROUILLE AMATEUR DANCE ORCHESTRA", "RADIO-SCHAERBEEK", "La Chocolaterie DUC", "La Maison VERELLEN", "FRISKO", "club 28"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Amédée Lijnen", "Henry Lemaire", "Ochs", "Ex", "P. oméo", "Dumoulin", "Jan Van Cleemput", "Ancia", "Marcel Antoine", "Francis André", "Hergé", "Kleo", "De Grove", "Jacques Laudy", "Jeanne Hovine", "Germaine Hagemans", "Van Deuren"],
#   "lieu": [],
#   "organisation": ["La Mine Souriante", "Galerie Kodak"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Léandre", "Abel Faivre", "Amédée Lynnen", "Ochs", "Roméo Dumoulin", "Henri Lemaire", "Ex", "Mme Jeanne Hovine", "Mlle Germaine Hagemans", "Jacques Laudy", "Fernand Scouflaire", "Albert Lepage", "Jan Van Cleemput", "Jean Ancia", "Georges", "Marcel Antoine", "Victor de Groux", "Heu", "Hergé", "Raoul Janssen", "Klec", "Max Servais", "Victor T'Sas", "T. Rompaey", "Armand Van der Elst", "Van Rompaey", "Wilcar", "Jacques Henriette", "Francis André", "Pitje Schramouille", "Jacques Bertrand"],
#   "lieu": ["Bruxelles", "Galerie Kodak", "boulevard parisien", "Zoo", "Théâtre du Marais"],
#   "organisation": ["Galerie Kodak", "Rataillon", "La Mine souriante", "Théâtre du Marais"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["M. Vanden Bossche", "M. Bovesse", "M. Faustus", "M. André", "M. Pierre Nothomb"],
#   "lieu": ["Palais d'Eté", "Moscou"],
#   "organisation": ["Radio-Schaerbeek", "I . N . R .", "T . S . F .", "Radio-Cointe", "Wallonia"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Faustus", "Vanden Bossche"],
#   "lieu": ["Bruxelles", "place de l'Yser", "boulevard d'Anvers", "boulevards du Centre", "place Rouppe", "rue du Midi", "Grand'Place"],
#   "organisation": ["Ligue de défense des sans-filistes", "Radio-Schaerbeek", "I . N . R .", "Maison flamande"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["M. Mestdagh", "M. Dochard", "M. Marcel Antoine"],
#   "lieu": ["Crainhem"],
#   "organisation": ["Radio Schaerbeek", "Radio-Schaerbeek"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine", "Ex", "Lempereur", "Jean Dratz", "Auguste Piccard", "Hindenburg", "Constant Van Offel", "James Ensor", "Amedée Lynen", "Mister Van", "Charlemagne", "Attila", "Henry Lemaire", "Ensor", "M. Lippens", "Maurice Gauchez", "Paul Leclercq", "Jean Ancia", "Ochs", "Ysaye", "Robert Vander Straeten", "Jean Marie Canneel", "Jean-Emile", "Albert Lenoir", "Swyncop", "Van Cleemput", "Scouflaire", "Rali", "Léo Jo", "Denise Beeli", "Henderyckx", "Guy Depière", "Nansef", "Vespasien", "Guillaume"],
#   "lieu": ["Belgique", "Paris", "Bruxelles", "Nord", "Sud", "Galerie de la Toison d'Or"],
#   "organisation": ["La Mine Souriante", "Académie de langue et de littérature"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": [
#     "Marcel Antoine",
#     "Welly Coupez",
#     "Marthe Coeck",
#     "Lily Bourget",
#     "Slache",
#     "René Picolo",
#     "Yvan Tiarto",
#     "Jules George",
#     "Longueval",
#     "Dedoncker",
#     "Assaignon",
#     "Delande",
#     "Minten",
#     "Herres",
#     "Cooremans",
#     "Goossens",
#     "Foulon",
#     "Ulens",
#     "Edouard Oostens",
#     "Van Eeckhout",
#     "Mazure",
#     "Kufferath",
#     "J . G . L ."
#   ],
#   "lieu": [
#     "Bruxelles",
#     "Théâtre Communal"
#   ],
#   "organisation": [
#     "Les Sans Nom",
#     "Le Progrès",
#     "Association des « Marçunvins »",
#     "Radio-Schaerbeek",
#     "la Monnaie",
#     "théâtre royal du Parc",
#     "le Grillon",
#     "Conservatoire Africain",
#     "Chambre de commerce française de Bruxelles",
#     "Assistance publique de Bruxelles",
#     "l'Assistance discrète au prétuberculeux",
#     "Hot and Swing"
#   ]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Dewandel", "Marcel Antoine", "Camille Fichefet", "Any Zador", "John Ouwerckx", "Rodney", "Brady"],
#   "lieu": [],
#   "organisation": ["Minstrels' Club Orchestra", "Bal du Tennis", "Les Cinq Svetlanow", "Les Zarowsky"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["René Picolo", "Fernand Coppieters", "Jean Malchair", "Michel Floro", "Marcel Antoine", "Berthe Coppi", "Antonio"],
#   "lieu": ["Bruxelles", "rue Auguste Orts"],
#   "organisation": ["Cercle Sportif du « Soir »", "La Grimace", "Académie du Chat noir", "Radio"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine", "Fernand Coppieters", "Lisé Coliny", "Lise Coliny"],
#   "lieu": ["Schaerbeek", "Bruxelles"],
#   "organisation": ["RADIO SCHAERBEEK-BRUX"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine"],
#   "lieu": ["Schaerbeek", "Bruxelles"],
#   "organisation": ["RADIO SCHAERBEEK-BRUX"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["M. Verryck", "M. Berryer", "Noël Barcy", "Esther Deltenre", "Rittche", "Festerat", "Marcel Antoine", "Miller", "Fanny de Real", "Gaby Letty", "Tony Early", "Tony Vaes", "Charles Tutéller"],
#   "lieu": ["Bruxelles", "Gaieté", "Scala"],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine", "Corn et Dixy", "Lewis Cools", "Joe Blendy", "Georgie Crane", "Marcel Etienne", "Dacosy", "Michel", "Wangermée", "Jean Delhez", "Elisabeth"],
#   "lieu": ["Bruxelles", "salle Patria"],
#   "organisation": ["Association des Libraires et Marchands de Journaux", "Association de la Corporation des journaux", "L’Harmonie Royale des Invalides", "L’Aide aux familles des mobilisés bruxellois", "œuvre Elisabeth « Pour nos soldats »"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Rittche", "Festerat", "J. Miller", "Léa Laurel", "Montaiols", "T. Early", "Chalin", "Tony Vaes", "Marcel Antoine"],
#   "lieu": [],
#   "organisation": ["Gaîté", "Gaîté Girls", "l'orchestre de Tony Vaes"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Jean Doisy"],
#   "lieu": ["BELGIQUE", "BRUXELLES"],
#   "organisation": ["STATIONS REGIONALES", "BRUXELLES-CONFERENCES", "Spirou"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine"],
#   "lieu": ["BELGIQUE", "BRUXELLES"],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine"],
#   "lieu": ["rue Auguste Orts"],
#   "organisation": ["Aidons-Nous", "Swing Lyceum"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["M. Sykes", "Marcel Antoine", "Rhum", "Mouché", "Trenet"],
#   "lieu": ["Landz", "Bruxelles"],
#   "organisation": ["Saint-Saveur"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Albert Sykes", "Strauss", "Hendels", "Puccini", "Mouehet", "Marcel Antoine", "Slache", "De Landy", "Trenet", "Rhum", "Fernandos", "Barbey d'Aurevilly", "Gaspari Feri", "Fernandos"],
#   "lieu": ["Paris", "Saint-Saveur", "banlieue"],
#   "organisation": ["Music-Hall du Saint-Saveur"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine", "René Piccolo", "Yvan Tiarko", "Yvette Valbrat", "Pol Bar", "Mme Bruzzi", "Alphonse Willy", "Alphonse Gilberte", "René Simon"],
#   "lieu": ["Bruxelles", "La Butte", "Le pont d'Avignon"],
#   "organisation": ["La Croix Blanche", "L'Agence Puput"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Jean Sello", "Rittche", "Simone Max", "Mills", "Simon", "Alvarez", "Léo Campion", "Marcel Antoine", "Christian", "André Mille", "Bob"],
#   "lieu": ["Le Tremplin", "rue de Fiennes", "Belgique", "Radio-Schaerbeek", "Mon Village", "Ancienne Belgique"],
#   "organisation": ["Oeuvre du Filleul Prisonnier", "stalag XIB"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine", "Jean Croixès", "Bitche"],
#   "lieu": ["rue joly"],
#   "organisation": ["Radio-Scnaerbeek"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": [
#     "Marcel Antoine",
#     "Richard Evans",
#     "Yvon De Bie",
#     "Bobby Naret",
#     "James H. Boyer",
#     "Hughes Knatchbull-Hugessen",
#     "Brugère",
#     "Tarleton",
#     "Hakewill-Smith",
#     "d'Oléon",
#     "Catteau",
#     "Oedenkoven",
#     "Brébart",
#     "M.-T. Rossel",
#     "Declercq",
#     "Lucien Fuss",
#     "Olivier Delville",
#     "Charles Gilles",
#     "Spencer Lock",
#     "Marthe Coeck",
#     "André Van Damme",
#     "Simone Lepage",
#     "Rosa Lagasse",
#     "Raymond Heux",
#     "Nancy Duval",
#     "Roger Crouquet"
#   ],
#   "lieu": [
#     "Bruxelles",
#     "Théâtre de la Monnaie",
#     "Paris",
#     "Strasbourg",
#     "Normandie",
#     "Bastogne",
#     "Ardennes",
#     "Escaut",
#     "Saint-Vith",
#     "Stavelot",
#     "Grande-Bretagne",
#     "France",
#     "République chinoise",
#     "liege"
#   ],
#   "organisation": [
#     "Le Soir",
#     "La Dernière Heure",
#     "Yvon De Bie and his all Belgian Band",
#     "433rd Army Services dance band",
#     "Lowlander's dance band",
#     "Guards division",
#     "107th army ground forces band",
#     "433rd Army service forces band",
#     "Division Leclerc",
#     "Brigade Piron",
#     "52e division écossaise",
#     "Grenadiers Guards",
#     "Soldiers', Sailor's and Airmen's families Association",
#     "garnison britannique de Bruxelles",
#     "mission militaire américaine",
#     "Théâtre royal de la Monnaie",
#     "ville de Bruxelles"
#   ]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Berthe Coppi", "Marcel Antoine", "Eddy Verrydt"],
#   "lieu": ["Bruxelles", "boulevard Anspach"],
#   "organisation": ["orchestre Eddy Verrydt"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Berthe Coppl", "Marcel Antoine", "Pierre Colson", "Robert Vanderstraeten", "Eddy Verrydt"],
#   "lieu": ["Bruxelles", "Bd Anspach"],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel ANTOINE", "René CLEREL", "René PICOLO", "Lui", "l'Autre", "Moi"],
#   "lieu": ["VIA MALA", "Pont-Neuf"],
#   "organisation": ["CABARET DE LA JOIE", "VIA MALA"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Henri Dulleu", "Willy Jad", "Marcel Antoine", "Marcel Rouls", "Merry Bourdon", "Eve Briac", "Roland de Saxe"],
#   "lieu": ["Forest"],
#   "organisation": ["collège échevinal", "fonds de solidarité forestoise"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Alice Rambert", "Marcel Antoine"],
#   "lieu": [],
#   "organisation": ["Ambrosinettes", "Bon Marché", "U.A.", "Caisse de Retraite"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Quievreux", "Marcel Antoine"],
#   "lieu": ["rue de la Longue Haie"],
#   "organisation": ["Rataillon"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": [
#     "Marcel Antoine",
#     "Fursy",
#     "Yvonne Sarcey",
#     "Henry Enthoven",
#     "Coco Lulu",
#     "Marcel Lefèvre",
#     "Hélène Lefèvre",
#     "Céel",
#     "George Garnir",
#     "Fernand Servais",
#     "Kervyn de Marcke ten Driesche",
#     "Jef Kazak",
#     "Jean d'Osta",
#     "Roméo Cariés",
#     "Bretonnière",
#     "Rina Ketty",
#     "André Mile",
#     "Zappy Max",
#     "Christian",
#     "Robert Carlier",
#     "Jacques Lippe"
#   ],
#   "lieu": [
#     "Paris",
#     "Montmartre",
#     "Bruxelles",
#     "Belgique",
#     "France",
#     "Angleterre",
#     "Allemagne",
#     "Koekelberg",
#     "Luxembourg",
#     "Hainaut"
#   ],
#   "organisation": [
#     "Conferencia",
#     "Association des chansonniers de Belgique",
#     "La Mine Souriante",
#     "L'Essor Intellectuel de Koekelberg",
#     "Pourquoi Pas",
#     "Radio-Schaerbeek",
#     "Radio-Luxembourg",
#     "Radio-Hainaut",
#     "Le Poulailler",
#     "Le Diable-au-Corps"
#   ]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine", "Simone Max", "Robert Carlier", "Jeannot", "Willy Clément", "Claude Valère", "Bares", "Pierre Gilbert", "Tchantchès", "Rouppe", "de Brouckere", "Anspach", "Buis", "De Mot", "Max", "Licas", "Licas II"],
#   "lieu": ["Bruxelles", "Grand-Place", "place Anneessens", "boulevards", "rue de l'Etuve", "rue du Chêne", "Paris", "Schaerbeek", "Neder-over-Heembeek", "Liège"],
#   "organisation": ["Amis de Manneken-Pis", "Union des Commerçants Midi-Bourse", "Het Sas", "Poulailler", "Théâtre des Deux Anes", "Chambre de Rhétorique du Parnassenberg", "Ecole d'accordéonistes Grégory", "Académie des Beaux-Arts", "Académie du Chat-Noir", "Navys Boys", "Harmonie Saint-André", "République liégeoise de D’ju d’là"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine", "J.-J. Martin", "Kari", "O. Siniaver", "Serge Creuz", "Sparmont", "Kali", "Scouflaire", "Martin", "Horn", "Ray Mu", "Alex", "Fédéri", "Van der Stijlac", "Capucine", "Gus", "Pouzet", "Dratz", "Alka", "Tenaz", "Moncassel", "Jules-Marie Canneel", "Cooremans", "Blum", "Janssens"],
#   "lieu": ["Bruxelles", "Galerie Lautrec", "Avenue de la Toison d’Or", "Mont-des-Airs", "Canal de Suez", "Tour de France"],
#   "organisation": ["La Mine souriante", "Manneken-Pis"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine", "Wuillot", "Quiévreux", "Mister Van", "Giraud-Mangin", "Albert Delvaux", "André Mile"],
#   "lieu": ["avenue de la Toison d'Or"],
#   "organisation": ["La Mine souriante"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Paul Nayaert", "Neuray", "Jean-Marie", "Polof", "Georges Rex", "Charles Tutelier", "Van Oost", "Marcel Antoine", "Blondin"],
#   "lieu": ["Belgique", "rue des Bouchers", "rue de Brabant", "rue Haute", "Louvain"],
#   "organisation": ["Belgique 1900", "commission consultative du folklore de « Belgique 1900 »"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine", "Théo Hannon", "Chrysobale Nipserc", "Longugus", "Louis Nossam", "Hamar", "Eleuthère-Pancrace Cucuchin Panch", "Mary Gasparoli", "Edmond Patris", "Sander Pierron", "Maurice Duwaerts", "Philippe Swyncop", "Dolf Ledel", "George Garnir", "Gustave Van Zype", "Firmin Baes", "Naeyaert", "Pierre NOVELIER"],
#   "lieu": ["Bruxelles", "Heysel", "Belgique"],
#   "organisation": ["La Mine souriante", "Association de la presse belge", "Belgique 1900", "Œuvre de la presse"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Max Léo", "Lyne Rolane", "Jo Terry", "Trebllle", "Marcel Antoine", "M. Dreze", "René Piret", "M. Muller", "M. Sweerts", "Van Offelen", "De Grauw", "Hougardy", "Janssens", "Blum", "Demuyter", "Martin", "Wiser", "Muller"],
#   "lieu": ["Etterbeek", "Wavre", "Bruxelles", "Ixellés", "Schaerbek"],
#   "organisation": ["L’Association libérale d’Etterbeek", "Fédération libérale de l’arrondissement de Bruxelles", "Domino Girls"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Esther Deltenre", "Henri Van Daele", "Jaak Borry", "Palmyre", "Alfred", "Julie", "Jan", "Omer Vande Gaer", "Elise Mertens", "Dany Christian", "Clemy Van Outryve", "Monique Van Dam", "Walter Richard", "J. Van Kerckhoven", "Ramacher", "Schalckens", "Marcel Antoine", "Verryck", "Cudell", "Van Leynseele", "De Boeck", "Nolard", "Warland", "Vandermeulen", "Stijns", "De Ruyter", "Callebaut", "Victor De Haeck", "Brûlez", "Ducq", "Elisabeth"],
#   "lieu": ["Bruxelles", "Gand", "Stuyvenberg", "rue des Croisades", "St-Josse"],
#   "organisation": ["Folies-Bergère", "Amis de Manneken-Pis", "Kinder-geluk", "Syndicat d'initiative", "Union internationale des journalistes", "Théâtre Flamand", "ministère des Affaires économiques"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["G . Etienne", "J . Lippe", "Jeanne Tony", "P . Polof", "R . Carlier", "Marcel Antoine", "Jean Marie", "Dany Walter"],
#   "lieu": [],
#   "organisation": ["bar MARTINI", "bar des Vedettes", "POULAILLER"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": [],
#   "lieu": [],
#   "organisation": ["COMITE NATIONAL DE L'HORLOGERIE"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["MARCEL ANTOINE", "ROBERT CARLIER"],
#   "lieu": ["RUE DES POISSONNIERS", "BELGIQUE", "Bourae", "l’Abbaye de THELEME"],
#   "organisation": ["CAVEAU VIENNOIS", "POULAILLER"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": [],
#   "lieu": [],
#   "organisation": ["fime duclou et cle", "COMITE NATIONAL DE L'HORLOGERIE"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": [],
#   "lieu": [],
#   "organisation": ["COMITE NATIONAL DE L'HORLOGERIE"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": [],
#   "lieu": [],
#   "organisation": ["COMITE NATIONAL DE L'HORLOGERIE", "fime duclou et cle"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine"],
#   "lieu": ["Bruxelles", "Schaerbeek", "Hainaut"],
#   "organisation": ["La Mine souriante", "Radio-Schaerbeek", "Radio-Hainout", "Sept jours de l'humour"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Georges ANTOINE", "Léon ANTOINE", "Marcel ANTOINE", "Léopold II"],
#   "lieu": ["Bruxelles", "Paris", "Ganshoren", "rue aux Laines", "rue du Pépin", "rue Dorian", "av. de la Constitution", "rue du Caprice"],
#   "organisation": ["la FAMILLE", "la Couronne", "la « Mine » souriante", "l'Ordre de Léopold II"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine", "Moncassel", "Ray-Mu (Demeulenaere)", "Jean-Marie de Ronchône", "baron Frédéric", "J .-J . Martin"],
#   "lieu": ["France", "Italie", "Belgique", "Galeries Anspach"],
#   "organisation": ["La Mine souriante"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": [
#     "Marcel Antoine",
#     "Beausillon",
#     "Deschamps",
#     "Demeulenaere",
#     "Martin",
#     "Jean-Marie de Ronchène",
#     "Lucien Cooremans",
#     "Van den Heuvel",
#     "René Dewaele",
#     "Williot",
#     "Schaelkens",
#     "De Haeck",
#     "Coppois",
#     "Dessart",
#     "Quiévreux",
#     "Marinùs",
#     "Delepine",
#     "Barrez",
#     "Arlette Vincent",
#     "Carlier",
#     "Lippe",
#     "Jean-Ceaude",
#     "Borra",
#     "Paul",
#     "Cooremans",
#     "J ;-M . Cannel",
#     "Moncassel",
#     "Ancia",
#     "Cracco",
#     "de Prittwitz",
#     "Lemaire",
#     "Liedel",
#     "Van Cleemputt",
#     "Vanderstraeten",
#     "Alka",
#     "Alex",
#     "Barrez",
#     "Bizuth",
#     "Boudart",
#     "Bubbs",
#     "Chain",
#     "Creuz",
#     "Horn",
#     "Karl",
#     "Leclerc",
#     "Lem",
#     "Lenoir",
#     "Mister Van",
#     "Movet",
#     "Noskoff",
#     "Ochs",
#     "Siniaver",
#     "Sprumont",
#     "Soler",
#     "Scouflaire",
#     "Tenax",
#     "Siné",
#     "Faisant",
#     "Folon",
#     "Attanasion",
#     "Ferrari",
#     "Walt Disney"
#   ],
#   "lieu": [
#     "Bruxelles",
#     "Galeries Anspach",
#     "Belgique"
#   ],
#   "organisation": [
#     "La Mine souriante",
#     "Galeries Anspach",
#     "Belgique Joyeuse",
#     "Chambre de Commerce",
#     "Association de la Presse",
#     "Amis de Mannekenpis",
#     "Loterie coloniale",
#     "Ommegang",
#     "Gaity"
#   ]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine"],
#   "lieu": ["Evere"],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine", "Mme Dergent", "Louis Van Cutsem", "MM . Schalckens", "Jacques Lippe", "De Muelenaere", "Gaston Williot", "Jane Tony"],
#   "lieu": ["Bruxelles", "Evere", "Ixelles", "Schaerbeek", "Molenbeek-St-Jean", "Belgique"],
#   "organisation": ["La Mine souriante", "Amis de Manneken-Pis", "chansonniers de Belgique", "Presse bruxelloise", "Les Amis de Marcel Antoine"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine"],
#   "lieu": [],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine"],
#   "lieu": [],
#   "organisation": ["COURRIER DES LETTRES DES ARTS ET DES SCIENCES", "PRIX MARCEL ANTOINE"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine", "Picha", "Crabbe", "J . Lippe", "R . P . Helbo", "Defoux"],
#   "lieu": [],
#   "organisation": ["Mine souriante", "XXXIe Salon des Humoristes"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Van Campenhout", "Théodore Verhaegen", "Auguste Orts", "Jacques-Louis David", "Marcel Antoine", "Louis Van Cutsem"],
#   "lieu": ["Evere", "Bruxelles", "Waterloo", "Afrique"],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Michel", "Marcel Antoine", "Horn", "Piron", "Martin", "Williot", "Jean Dratz", "Philipps", "Van Beuren", "Cudell", "Mardulyn", "Holender", "Randaxhe", "Peter Ier de Kersterbeek"],
#   "lieu": ["Bruxelles", "Eupen", "Schaerbeek", "St-Josse-ten-Noode", "Centre Rogier", "Indes", "Mexique", "Brésil", "Vietnam", "Maroc"],
#   "organisation": ["La Mine souriante", "Association générale de la pression belge", "Amis de Manneken-Pis", "Union belge pour la défense de la paix"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine", "Horn", "Georges Konen", "Piron", "Martin", "Jean Dratz"],
#   "lieu": ["Eupen"],
#   "organisation": ["La Mine souriante", "T.V."]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine"],
#   "lieu": ["place Rogier", "Belgique"],
#   "organisation": ["La mine souriante", "Salon des humoristes", "Syndicat d'initiative"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Peynet", "Katz", "Bench", "Ploeg", "Vicq", "Paul Derman", "Marcel Antoine"],
#   "lieu": ["place Rogier", "Bruxelles"],
#   "organisation": ["Syndicat d’initiative", "Commission d’animation du centre de Bruxelles", "La Mine souriante"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine"],
#   "lieu": ["Namur"],
#   "organisation": ["Radio-Schaerbeek", "Ordre de la Couronne", "Mine Souriante", "Bourse de Namur"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Emile-André Robert"],
#   "lieu": ["Binche"],
#   "organisation": ["TSF RADIO-BINCHE", "Spirou"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine"],
#   "lieu": ["BRUXELLES"],
#   "organisation": ["TSF BRUXELLES-CONFERENCES"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Claude RENAUDY", "Paul Winckler", "M. Pel Ducca", "M. Lotare Vecchi", "L. HOUBEAU"],
#   "lieu": ["Paris", "Belgique", "France"],
#   "organisation": ["Opéra-Mundi", "Journal de Mickey", "Robinson", "Hop-là !", "Le Petit Vingtième", "Petits Belges", "Le Croisé", "Pierrot", "Lisette", "Semaine de Suzette", "Benjamin", "Bonne Presse", "Presto-Films", "Collection Printemps", "Les Livres Roses pour la jeunesse", "Spirou", "Dick Tracy", "Marc-Hercule", "Hurrah !", "Aventureux", "Jumbe", "Aventures"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Jean Doisy"],
#   "lieu": ["Binche"],
#   "organisation": ["T . S . F . RADIO-BINCHE"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Jean Doisy"],
#   "lieu": ["Binche"],
#   "organisation": ["TSF RADIO-BINCHE"]
# }
# RESPONSE CONTENT:
#  {"personne": ["Slache"], "lieu": ["Luxemburg"], "organisation": ["RADIO PROGRAMMA'S"]}
# RESPONSE CONTENT:
#  {
#   "personne": ["Slache"],
#   "lieu": ["Luxemburg"],
#   "organisation": ["RADIO PROGRAMMA'S"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Slache"],
#   "lieu": ["Luxemburg"],
#   "organisation": ["RADIO PROGRAMMA'S"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["H. LEGROS", "TRUFFAUT", "HUBIN", "FIEULLIEN", "VAN GLABBEKE", "HUYSMANS", "VANDERVELDE", "Koning"],
#   "lieu": ["Wallonië", "Luik"],
#   "organisation": ["Kamer", "Senaat", "L'Action Wallone", "regering", "beroepshof"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Roi", "Hitler", "G. Truffaut"],
#   "lieu": ["Liège"],
#   "organisation": ["L'Action Wallonne", "Parquet de Liège"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine"],
#   "lieu": [],
#   "organisation": ["RADIO-BELGIQUE"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine", "Thelma", "Telma", "Tchaikowsky", "Saint-Saêns", "G . Pierné", "Marssenet"],
#   "lieu": [],
#   "organisation": ["RADIO-BELGIQUE"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Arthur Navez", "Franz Hais", "Roméo Dumoulin", "Lempereur", "Léo Jo", "Jeanne Hovine", "H. Lemaire", "Fernand François", "Marcel Antoine", "Jeann Ancia", "J. M. Canneel", "A. Van der Elst"],
#   "lieu": ["Galerie Larribe"],
#   "organisation": ["La Mine souriante", "Les Syndics de la Zwanze"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Godefroid du Baillon", "Marcel Antoine"],
#   "lieu": [],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine"],
#   "lieu": [],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine"],
#   "lieu": ["Chine"],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Hindenburg", "Brüning", "Marcel Antoine"],
#   "lieu": ["ALLEMAGNE", "France", "Angleterre"],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine"],
#   "lieu": [],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["HITLER", "VANDERVELDE"],
#   "lieu": ["ROME", "SALON DE L'ALIMENTATION", "rue"],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Al Capone", "Marcel Antoine"],
#   "lieu": ["CHICAGO", "BAR LE-DUC"],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Piccard", "Marcel Antoine"],
#   "lieu": ["AUGSBOURG"],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine", "Alfred", "Mariette", "Monsieur Piccard", "seigneur de Doorn"],
#   "lieu": ["Brésil", "lune"],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Maurice", "EMILE", "GASTOUNEET"],
#   "lieu": ["NICE", "SALON DE LA T.S.F."],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Emile", "Cicil Sorel", "Marcel Antoine"],
#   "lieu": ["Chine"],
#   "organisation": ["COMEDIE-FRANCAISE"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": [],
#   "lieu": [],
#   "organisation": ["LA SEMAINE DU LIVRE BELGE"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Leloutre", "Marcel Antoine"],
#   "lieu": ["PALAIS-BOURBON"],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine", "Gaby"],
#   "lieu": ["Paris"],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine", "Hitler", "TARDIEU"],
#   "lieu": ["SAINT-NICOLAS"],
#   "organisation": ["SALON DE L'AUTO"]
# }
# RESPONSE CONTENT:
#  {"personne": ["Marianne", "Marcel Antoine"], "lieu": ["Valence"], "organisation": []}
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine", "M. STEEG", "CHEVALIER", "Hitler"],
#   "lieu": ["Espagne"],
#   "organisation": []
# }
#  Non, plutôt
# {
#   "personne": ["Marcel Antoine", "M. STEEG", "CHEVALIER"],
#   "lieu": [],
#   "organisation": []
# }
# En effet, HITLERIENS fait référence à des partisans d'Hitler et non à Hitler lui-même, et ESPAGNOLS fait référence à un peuple ou à une entité géographique non spécifique.
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine"],
#   "lieu": [],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Emile", "Hitler", "Maurice Chevalier", "Briand", "Mussolini", "Steeg", "Marcel Antoine"],
#   "lieu": ["France"],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Vauthier", "Georges Carpentier", "Marcel Antoine"],
#   "lieu": ["AMERIQUE"],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Madame Hanau", "Marcel Antoine", "Vauthier", "HITLER"],
#   "lieu": ["Londres"],
#   "organisation": ["l'asile d'aliénés", "Le choeur des libéraux"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine", "Steeg"],
#   "lieu": ["Paris"],
#   "organisation": ["ELECTIC DE MISS PARIS"]
# }
# RESPONSE CONTENT:
#  {"personne": ["Marcel Antoine"], "lieu": [], "organisation": []}
# RESPONSE CONTENT:
#  {
#   "personne": ["Emile", "Marcel Antoine", "Max"],
#   "lieu": [],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine"],
#   "lieu": [],
#   "organisation": ["Cinémachin Film Sonore"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["TORO", "BERENGUER", "ALPHONSE", "Marcel Antoine"],
#   "lieu": [],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Lady Owen", "Marcel Antoine"],
#   "lieu": [],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Gandhi", "Alphonse", "Briand", "Franklin-Bouillon", "Mussolini", "MacDonald", "Marcel Antoine"],
#   "lieu": ["Indes", "Belgique", "France", "Allemagne"],
#   "organisation": ["OFFICE NATIONAL DU TOURISME", "Vice-Roi"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Gandhi", "Marcel Antoine"],
#   "lieu": ["GUYANE", "PALAIS BOURBON"],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["CINE MACHIN ALMAZOFF", "PRINCE RIGAUDIN", "Mme Almazoff", "M. Benoist", "Marcel Antoine", "M. le Directeur général"],
#   "lieu": [],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine"],
#   "lieu": [],
#   "organisation": ["I . N . R ."]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine"],
#   "lieu": ["Kiki Le Groenendael club"],
#   "organisation": ["Kiki Le Groenendael club"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Cornellie", "Charlot Decore", "Maurice", "Marcel Antoine"],
#   "lieu": ["LOUVAIN"],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine"],
#   "lieu": [],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Ladoumegue", "Gustave", "Marcel Antoine"],
#   "lieu": [],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine"],
#   "lieu": [],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine"],
#   "lieu": [],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine"],
#   "lieu": [],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Joséphine Baker", "Marcel Antoine", "Diagne"],
#   "lieu": ["Vincennes", "Angkor"],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Doumergue", "Doumer", "Marcel Antoine", "Doumer-Deus"],
#   "lieu": ["VERSAILLES"],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Bovesse", "PETITJEAN", "M. VAUTHIER", "de Broqueville", "Marcel Antoine", "FORTHOMME"],
#   "lieu": [],
#   "organisation": ["LE BANC PARLEMENTAIRE"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Aristide", "Franklin-Bouillon", "Renkin", "Piccard", "Marcel Antoine"],
#   "lieu": ["GARE DE LYON"],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Renkin", "Cocq", "Poullet", "Moutart", "Marcel Antoine"],
#   "lieu": ["Sciences et Arts"],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Coppée", "Petitjean", "Marcel Antoine"],
#   "lieu": ["Rome"],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine", "Franklin-Bouillon"],
#   "lieu": ["Bovesse", "Nameur"],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Sam", "Marianne", "M. Hoover", "Marcel Antoine"],
#   "lieu": ["Belgique"],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Monsieur l'Maîeur", "Christian", "Cyrano", "Marcel Antoine"],
#   "lieu": ["NAMUR", "ROXANNE"],
#   "organisation": ["LE BALCON DE ROXANNE"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Luther", "Marcel Antoine"],
#   "lieu": ["Europe", "France"],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine"],
#   "lieu": [],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Dick", "Brüning", "Laval", "Marcel Antoine"],
#   "lieu": ["Londres", "AMERIQUE"],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine", "Gastounet"],
#   "lieu": ["RAMBOUILLET"],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Curtius", "Bruning", "M. Mussolini", "Oustric", "Gualino", "Hindenburg", "Mme Doumer", "Paul", "Marcel Antoine"],
#   "lieu": ["Rome", "Menton"],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Aristide", "Pierre", "Marcel Antoine"],
#   "lieu": ["Berlin"],
#   "organisation": ["LES « SINGERES »"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine"],
#   "lieu": [],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Gandhi", "Marcel Antoine", "Mahatma"],
#   "lieu": [],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["GANDHI", "MARIUS", "Mahatma", "Marcel Antoine"],
#   "lieu": ["Bruxelles"],
#   "organisation": ["Congrès de la Parole"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Oustric", "Ganhdi", "Marcel Antoine"],
#   "lieu": ["Marseille", "rue de Flandre"],
#   "organisation": ["Fils du Ciel"]
# }
# RESPONSE CONTENT:
#  {"personne": ["Marcel Antoine"], "lieu": ["Laval"], "organisation": []}
# RESPONSE CONTENT:
#  {
#   "personne": ["Maurice", "Briand", "Marcel Antoine"],
#   "lieu": ["Amérique"],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine", "Briand", "Léon", "Mr BLUM", "MacDonald"],
#   "lieu": ["WASHINGTON", "Japon"],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine"],
#   "lieu": [],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["M. Bovesse", "M. Charles Bernard", "M. Franqui", "Marcel Antoine", "Laval"],
#   "lieu": [],
#   "organisation": ["Bottin"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Serge de Lenz", "Marcel Antoine"],
#   "lieu": ["Midi", "Corse"],
#   "organisation": ["Jésuites"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Jules", "Serge de Lenz", "Marcel Antoine"],
#   "lieu": ["Paris"],
#   "organisation": ["Cirque Serrasani", "Société des Beaux-Arts"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine"],
#   "lieu": [],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Saint Nicolas", "Hitler", "Kreglinger", "Serge"],
#   "lieu": [],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine"],
#   "lieu": [],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["M. le Ministre Bovesse", "P. Bovesse", "M. Vos", "De Jaeck", "Dr. Borms", "Hip. Meert", "Dr. Depla", "Herman Van den Reeth", "les frères de Rudder", "Martin Rudelshelm", "le père Hainaut", "M. Vos"],
#   "lieu": ["Belgique", "Flandre", "Bruxelles", "Brabant", "Groenlnghe"],
#   "organisation": ["Chambre", "Vlaamsche Naitonale Radiovereeniging", "Vlanara O. R.", "Institut national de radiophonie", "IT N. R.", "Raad van Vlaanderen", "Cour d'assises de Bruxelles", "Conseil de guerre du grand quartier général"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Hymans", "Renkin", "Marcel Antoine", "Koutiépof"],
#   "lieu": ["Londres", "Angleterre", "Manche"],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine"],
#   "lieu": [],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine", "Briand"],
#   "lieu": ["BRUXELLES", "Bâle"],
#   "organisation": ["SIX JOURS DE BRUXELLES", "LA PAILLE ET LA POUTRE"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Brûning", "Hitler", "Laval", "Marcel Antoine"],
#   "lieu": ["Lausanne"],
# ...
#  {
#   "personne": ["Marcel Antoine", "Albert Lenoir", "Lemaire", "Geo Vermeire", "Jean-Leo", "Bob Boudart", "Fernand Janson", "Raoul Janssen", "Servais", "Christiane Laude", "Louis Van Cutsem", "Broodcoorens", "G"],
#   "lieu": ["Bruxelles", "rue Neuve"],
#   "organisation": ["Gestapo"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine"],
#   "lieu": ["rue d'Anderlecht"],
#   "organisation": ["la Mine Souriante", "les Humoristes de la Mine Souriante"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine", "James Boyer", "Captain Richard Evans", "Yvon De Ble", "Bobby Naret", "Marthe Coeck", "André Van Damme", "Raymond Heux", "Simone Lepage", "Rosa Lagasse", "Bruneels", "von Rundstedt", "Piron", "Léopold II"],
#   "lieu": ["Bruxelles", "Japon", "Bastogne", "Paris", "Strasbourg", "Normandie", "Wessel", "Escaut", "Liège", "Place de la Monnaie"],
#   "organisation": ["La Dernière Heure", "Le Soir", "B.B.C.", "Guards Division", "Airborne Division", "Division Leclerc", "Brigade Piron", "52e Highland Division", "A.T.S."]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Eddie", "Christiane Houdez", "Marcel Antoine", "Anny Godet", "Bichette Ferna", "Max Eddie", "Vivette", "Rudy Windsor", "Gaston Raskin"],
#   "lieu": ["LA CAPITALE"],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Berthe Coppi", "Marcel Antoine", "Eddy Verrydt"],
#   "lieu": ["Bruxelles", "Bd Anspach"],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Coelst", "Hendrickx", "J . De Boeck", "Max", "Jacqmain", "Louis Vogels", "Brabant", "Jonau", "Van de Plassche", "Mertens", "Delporte", "le Thoor", "William", "Marcel Antoine"],
#   "lieu": ["Laeken"],
#   "organisation": ["Cercle d'études musicales l' «Iris»", "Croix-Rouge", "Hôtel communal"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine"],
#   "lieu": ["rue du Congrès"],
#   "organisation": ["L'Union Radio-Club de Belgique", "Société Royale «L'Orphéon de Bruxelles»", "Cercle Symphonique de la Grande Harmonie de Radio-Belgique", "Grande Harmonie"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": [
#     "Charles Bernard",
#     "Mme Charles Bernard",
#     "Ansel",
#     "Finet",
#     "Hislaire",
#     "Tytgat",
#     "Paulus",
#     "Bonnelain",
#     "Hyppolite Daeye",
#     "Massonaet",
#     "Louis Piérard",
#     "Van Remoortel",
#     "Verboom",
#     "Ewbank",
#     "Golstein",
#     "Jules Gibet",
#     "Claire Gérard",
#     "Jean Dess",
#     "Marcel Antoine",
#     "Demuyter",
#     "Coekelberg",
#     "Pierre Fontaine",
#     "Mme Eugenia Buyko",
#     "Krumme"
#   ],
#   "lieu": [
#     "Sept Fontaines",
#     "Soignes",
#     "Alsemberg"
#   ],
#   "organisation": [
#     "Rouge et Noir",
#     "Fidèles du Rouge et du Noir",
#     "Nation Belge",
#     "Cygne"
#   ]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine", "Robert Jonckheere", "Colruyt", "Van Hyfte", "Carion", "Van Beneden", "Piccolo", "Mlle Derville", "Léo Drix"],
#   "lieu": ["Bruxelles", "Liège", "Marcinelle", "Ostende"],
#   "organisation": ["L'Etincelle", "Kursaal"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine"],
#   "lieu": [],
#   "organisation": ["Institut National Belge de Radio diffusion"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Alex Mondose", "L. Harzé", "Aldo Pégoli", "G. Straek", "Bastin", "L. Duriux", "Marcel Antoine", "Francis Clarel", "Michel Floro"],
#   "lieu": ["Bruxelles", "Grand Place"],
#   "organisation": ["Académie du Chat Noir", "société royale « La Charité »", "Cercle Brugeois", "Œuvres patronnées par le Cercle Brugeois"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine"],
#   "lieu": [],
#   "organisation": ["Institut National Belge de Radio diffusion"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Albert", "Wagemans", "Baril", "Leuridan", "Renoz", "Decae", "Genotte", "Van Espen", "Fauconnier", "Beréas", "Colin", "Van Elewyck", "Beaupin", "Degreef", "Limbourg", "Neels", "Vermeylen", "Spoel", "Alfred Mahy", "Germain Lucigny", "Fany Prils", "Savières", "Schouten", "De Coene", "Lucigny", "Marcel Lucigny", "Marcel Antoine", "Géo Burtin"],
#   "lieu": ["Patria", "Bruxelles"],
#   "organisation": ["Amicale des Carabiniers cyclistes", "Fraternelle des Diables Noirs 1914-18", "U.F.A.C.", "1er régiment des Carabiniers-Cyclistes", "section bruxelloise de la fraternelle", "Génie", "musique du 8e de Ligne", "Diables Noirs"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Mme Laisnez", "Paulsen", "Melckmans", "Mlles VanHamme", "Thibau", "G. Vaxelaire", "Mme Veretegen", "Thonus", "Wilmet", "Dolhain", "Mme de Marny", "Marcel Loiseau", "Léo Marco", "Jules Roosen", "Marcel Savières", "Gaby Haubien", "Leblanc", "Marcel Antoine", "André", "Mme Keels", "Bizet", "Puccini", "Schuman", "Halévy"],
#   "lieu": ["Anderlecht", "Patria", "Pologne", "Théâtre du Parc"],
#   "organisation": ["La Croix-Rouge de la Jeunesse d'Anderlecht"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Mestdagh", "Dochard", "Marcel Antoine", "Faustus"],
#   "lieu": ["Crainhem"],
#   "organisation": ["Radio Schaerbeek"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine"],
#   "lieu": ["Bruxelles"],
#   "organisation": ["Radio-Schaerbcek-Bruxelles"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine"],
#   "lieu": ["Bruxelles"],
#   "organisation": ["Radio-Schaerbeek-Bruxelles"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Mme Clairbert", "André d'Arkor", "Van Obbergh", "Germaine d'Astru", "Bella Darms", "Ambrosiny", "Jongen", "Marcel Antoine", "Bastien", "Apol"],
#   "lieu": ["Palais des Beaux-Arts"],
#   "organisation": ["Blue Blithe Players Orchestre", "conservatoire", "Villa Chez Nous"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["M. O. Biltiau", "Soupart", "Blum", "Dejase", "Carton", "Fraikin", "Lenoir", "De Block", "Ekmant", "Vuga", "Vermeersch", "Marcel Antoine", "Myrima Dariam", "Mme Ramone", "Libeau", "Miss Belgique 1934"],
#   "lieu": ["Schaerbeek", "hôtel communal"],
#   "organisation": ["groupement postscolaire de Schaerbeek", "Gaity"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine"],
#   "lieu": ["Heysel"],
#   "organisation": ["Protection"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine", "Edith Cavell"],
#   "lieu": ["Arles", "La Camargue", "Les Saintes"],
#   "organisation": ["La Besace"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Reine Elisabeth", "M. Adolphe Max", "M. Marcel Antoine", "Reine Astrid"],
#   "lieu": ["Borinage", "Théâtre des Galeries", "Heysel", "Wasmes", "Bruxelles", "Riga", "rue des Fripiers", "chaussée de Wavre"],
#   "organisation": ["La Maison des Invalides", "La Protection", "cercle choral Fidelio"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine", "Reine Astrid"],
#   "lieu": ["Borinage", "Théâtre des Galeries", "Heysel", "Wasmes", "Bruxelles", "Riga", "place de Brouckère", "rue des Fripiers", "chaussée de Wavre"],
#   "organisation": ["La Maison des Invalides", "Protection", "Fidelio", "Nation Belge"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine"],
#   "lieu": ["Bruxelles", "Wasmes", "Borinage", "Heysel"],
#   "organisation": ["Cercle Choral « Fidélio »", "Protection", "PATRIA"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Henri de Bornier", "Marcel Antoine", "Max", "Denise Beeli", "Bastien", "J. M. Canneel", "Paul-Henri Spaak", "Albert Lenrir", "Robert van der Straeten", "Jeanne Hovine", "Marie Dubas", "Lempereur", "van Cleemput", "Léo Jo", "Henderyckx", "Henry Lemaire", "Louis Lou", "Scouflaire", "Rali", "T'Sas", "Wilcar", "Jacques Ochs", "Happy"],
#   "lieu": ["Galerie de la Toison d'Or"],
#   "organisation": ["La Mine Souriante"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["M. Max", "Mme Fonck", "François", "Dr Lust", "Buyssens", "Puttemans", "Van Neck", "P. Celis", "O. Gossens", "Marcel Antoine", "M. Cuvelier", "M. Péruchet"],
#   "lieu": ["Bruxelles"],
#   "organisation": ["Royaume des Enfants", "Exposition"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Amédée Lynen", "Jan van Cleemput", "J .-M . Canneel", "Scouflaire", "Denise Berli", "Jacques Ochs", "F . Janson", "Henry Lemaire", "Albert Lenoir", "Van Bueren", "Van der Straeten", "Vermeire", "Spermont", "Pierre Daye", "Léon Degrelle", "Ancia", "Marcel Antoine", "Victor Degroux", "Leclercq de Ste Haie", "Lempereur", "Lou", "Michiels", "Rosty", "Rail", "Ray Ber", "Ray De Meulenaere", "Stiasteny", "Van Caulaert", "Wilcar", "Permeke"],
#   "lieu": ["Galerie de la Toison d'Or", "Bruxelles"],
#   "organisation": ["La Mine Souriante", "gardecivique"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Claude Robert", "Nicole", "Rolan", "Georges De Hens", "Hoffman", "Daemen", "Marcel Antoine"],
#   "lieu": ["Antilles"],
#   "organisation": ["L'Association des Anciens Eleves de L'Academie des Beaux-Arts", "The Collegian's Orchestra", "Académie des Beaux-Arts"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine"],
#   "lieu": ["Laeken", "rue Tïelemans"],
#   "organisation": ["Réveil Intellectuel"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine", "René De Bock"],
#   "lieu": ["Théâtre Continental", "chaussée de Wavre", "avenue des Casernes", "rue Général Laman"],
#   "organisation": ["l'Eclair Etterbeekois"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine", "Egide Van Gils", "M . Th . Meuwèse"],
#   "lieu": ["New-York", "Porte Louise", "boulevard de Waterloo", "Résidence Palace"],
#   "organisation": ["Minstrels club Orchestra", "Slache"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine"],
#   "lieu": ["Madeleine", "St-Gilles", "Alsemberg"],
#   "organisation": ["Soutien de Saint-Gilles", "Ballet Blanc du Soutien de St-Gilles", "Packay's Swing Academy"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Longueval", "Verheven", "Marcel Antoine"],
#   "lieu": ["Bruxelles", "rue du Chêne", "rue du Poinçon"],
#   "organisation": ["Les Sans Nom", "Cercle"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Esther Deltenre", "Rittche", "Festerat", "Jef Miller", "Tony Early", "Fanny de Real", "Gaby Letty", "Paul France", "Marcel Antoine", "Tony Vaes"],
#   "lieu": ["Bruxelles"],
#   "organisation": ["Gaite", "Galty-Girls"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Noël Barcy", "Esther Deltenre", "Rittche", "Festerat", "Jef Miller", "T . Early", "Paul France", "G . Letty", "Fannv de Réal", "Marcel Antoine", "Tony Vaes"],
#   "lieu": ["Bruxelles", "Gaîté"],
#   "organisation": ["Gaity Glrls", "Tony Vaes et son orchestre"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Esther Deltenre", "Rittche", "Fosterat", "Jef Miller", "Tony Early", "P. France", "F. de Réal", "G. Letty", "Marcel Antoine", "Tony Vaes"],
#   "lieu": ["Bruxelles"],
#   "organisation": ["Gaity Girls", "Théâtres"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine"],
#   "lieu": ["Brux"],
#   "organisation": ["T . S . F ."]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Nora Divry", "Paul Reval", "Marcel Antoine"],
#   "lieu": ["Saint-Gilles", "Paris", "Bruxelles"],
#   "organisation": ["Garde Civile territoriale de Saint-Gilles", "service Police-Incendies", "Aidez-Nous"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["M. Pepermans", "Marcel Antoine", "Alice Meva", "Freddy Northon", "capitaine De Ceuninck"],
#   "lieu": ["salle de la Madeleine"],
#   "organisation": ["Grenade", "Oeuvre d'Entr'aide aux mobilisés des régiments des Grenadiers", "1er régiment des Grenadiers", "Clique du régiment"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Jean Delhez", "Marcel Antoine", "Marcel Etienne", "la Reine Elisabeth"],
#   "lieu": ["Patria", "Théâtre Patria", "rue du Marais", "Bruxelles", "Ville de Bruxelles"],
#   "organisation": ["l'Association des Vendeurs de journaux de Bruxelles", "l'Œuvre Elisabeth « Pour nos soldats »", "l'Œuvre des Familles Nécessiteuses des Mobilisés Bruxellois", "l'Harmonie Royale des Militaires Mutilés et Invalides"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine"],
#   "lieu": ["Bruxelles", "France", "Saint-Sauveur"],
#   "organisation": ["La Mine Souriante"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine", "Mouchet", "De Landy", "Félia Doehaert", "Gaspart Féri", "Rhum", "Fernando", "Sykes"],
#   "lieu": ["Bruxelles", "Concert-Music-Hall Saint-Sauveur"],
#   "organisation": ["Sykes et son orchestre"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine", "Mouchet", "De Landy", "Félia Doehaert", "Gaspart Féri", "Rhum", "Fernando", "Sykes"],
#   "lieu": ["Bruxelles", "Concert-Music-Hall Saint-Sauveur"],
#   "organisation": ["Sykes et son orchestre"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine", "Sykes", "Slache", "Toutouneke", "Louis Melon", "De Landy", "Trenet", "Mouchet", "Gaspart Féri", "Félia Dochaerd", "Rhum", "Fernando", "Henrotte", "Boum-Boum", "Emile Zola"],
#   "lieu": ["Bruxelles", "Sainte-Gudule", "Schaerbeek", "Paris", "Jonction", "Radio-Bruxelles", "Gand"],
#   "organisation": ["Music-Hall Saint-Sauveur", "8e régiment de ligne", "l'CEuvre Elisabeth", "Cirque Médrano", "Cirque Fernando"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Sykes", "Marcel Antoine", "Slache", "Olive", "Toutouneke", "Suzy Roy", "Zarah Léander", "Mouchet", "Serge", "Mia Karine", "Luciana", "Rubens", "Gaspard Féri", "Félia Doehaerd", "Rhum", "Fernando", "J . L"],
#   "lieu": ["Saint-Sauveur", "Belgique"],
#   "organisation": ["Music-Hall du Saint-Sauveur", "orchestre de Sykes"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine", "Rhum", "Fernando", "Sykes"],
#   "lieu": ["Bruxelles", "St-Sauveur"],
#   "organisation": ["Slache National"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine", "Mary Camus", "Germaine Benoist", "Ilia Iankoff", "Dorita", "Félia Douhard", "Mouchet", "Sykes"],
#   "lieu": ["Bruxelles", "SAINT-SAUVEUR"],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine", "Mary Camus", "Germaine Benoist", "Ilia Iankoff", "Dorita", "F'-ilia Douhard", "Mouchet", "Sykes"],
#   "lieu": ["Bruxelles"],
#   "organisation": []
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine", "Mary Camus", "Germaine Benoist", "Ilia Iankoff", "Dorita", "Félia Douhard", "Mouchet"],
#   "lieu": ["Bruxelles", "SAINT-SAUVEUR"],
#   "organisation": ["Sykes"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["François", "Marcel Antoine", "Roméo Dumoulin", "Henri Lemaire", "Léo Jo", "Ancia", "Francis André", "Van Cleemput", "Lempereur", "Moedyck", "Rali", "Ensor", "Hergé", "Teddy Van Beuren", "Jean-Emile", "Canneel", "'t Sas", "Hovine", "Vanderelst", "Lenoir", "Bossaerts", "Marcel ROVAIN"],
#   "lieu": ["Bruxelles", "Porte de Namur", "Galerie Larribe", "Verviers"],
#   "organisation": ["La Mine Souriante", "Association des Humoristes", "Galerie Larribe"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Marcel Antoine", "Ancia", "de Groux", "Romeo Dumoulin", "Ex", "Jacques Henriette", "Hergé", "Klec", "Lenoir", "Ochs", "'t Sas", "Max Servais", "Van der Elst", "Wilcar", "Amédée Lynen", "Germaine Hagemans", "Henri Lemaire", "L. T.", "René CLERIAXE", "Mistinguett", "Tardieu", "Daudet"],
#   "lieu": ["Paris", "Bruxelles", "avenue de la Toison d'Or", "Belgique"],
#   "organisation": ["Académie de Belgique", "Salon des Humoristes"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["François Bovesse", "L. Mestdagh", "Faustus", "Guernier", "Loppens", "Coelst", "Wauwermans", "Waucquez"],
#   "lieu": ["Bruxelles", "Belgique", "avenue Claeys"],
#   "organisation": ["Radio-Schaerbeek", "parti catholique", "parti radical"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Labiche", "Ed. Bourdet", "A.-J. Antoine", "M. Léry", "Lavedan", "Pierre Frondaie", "Croué", "Copeau", "G. Rency", "Edm. Rostand", "André Bisson", "Birabeau", "Marcel Espaux", "Gordeaux", "Feluy y Codina", "J.-J. Bernard", "Tristan Bernard", "Pagnol", "Nivoix", "Duvernois", "G.-G. Toudouze", "Marcel Achard", "Pierre Van Beneden", "Daniel Régnier", "Franz Dezwaef", "Rickal", "Frisque", "Joachain", "Gerlache", "Marcel Antoine"],
#   "lieu": ["Bruxelles", "Salle Patria"],
#   "organisation": ["L'Etincelle"]
# }
# RESPONSE CONTENT:
#  {
#   "personne": ["Amédée Lynen", "Marcel Antoine", "J.-M. Canneel", "Jan van Cleemput", "Mme Beeli", "Henri Lemaire", "James Ensor", "Frans Thys", "Naureff", "Ray-Ber", "Fernand Scouf", "Tony Stiasteny", "Paul Leclercq de Sainte-Marie", "Louis van Cutsem", "M. Max", "Guy Depierre", "Degroux", "Elmer", "T'Sas", "Mic", "Shirley", "Marlène", "Maë West", "Spermond", "Lenoir", "Jan", "Geo Vermelre", "Jacques Ocht", "ARGO"],
#   "lieu": ["Galerie de la Toison d'Or"],
#   "organisation": ["La Mine Souriante", "La Comédie Humaine"]
# }

# %%
df_output.head()

# %%
flat_json_output = [
    {
        "filename": key,
        "text": value["text"],
        "cleaned_text": value["cleaned_text"],
        "people": ", ".join(set(value["people"])), 
        "locations": ", ".join(set(value["locations"])),
        "organisations": ", ".join(set(value["organisations"]))  
    }
    for key, value in json_output.items()
]
import json
output_file2 = "flat_llama_results.json"
with open(output_file2, "w", encoding="utf-8") as f:
    json.dump(flat_json_output, f, indent=4, ensure_ascii=False)

print(f"flat NER results saved to {output_file2}")
